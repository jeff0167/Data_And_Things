# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv("../Notebooks and data-9/diabetes.csv") # this is just for reference to look at
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
X = df[["Glucose", "BloodPressure", "Insulin", "Outcome"]]
X
# Out:
#      Glucose  BloodPressure  Insulin  Outcome
# 0        148             72        0        1
# 1         85             66        0        0
# 2        183             64        0        1
# 3         89             66       94        0
# 4        137             40      168        1
# ..       ...            ...      ...      ...
# 763      101             76      180        0
# 764      122             70        0        0
# 765      121             72      112        0
# 766      126             60        0        1
# 767       93             70        0        0
#
# [768 rows x 4 columns]

# %%
y = df["Outcome"]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# The publisher publishes records in S continuously. When it reaches the end of S, it continues to send from the beginning again.
#
# The subscriber continuously receives the data. For each latest record(r) received, apply the 3NN classification to the last 5 records before r, and compare the classification result with the Outcome label in r.
#
#     Repeat this for 1000 times, and report the number of correct classifications.
#
#     Question: "apply the 3NN classification to the last 5 records before r" is ambigous, is it from 0 - (len(list) - 5) or (len(list) - 5) - len(list)
#     One intepretation would only ever test with the five latest records before r, the other would take all the records - the last 5 before r
#     one: 5, the other is ever increasing, and ever more acurate, though also ever more computational expensive
#     I must assume it would be the later, you want to train a model on new data in addition to what you already have to improve your model

# %%
def calculate_3nn_with_train_test(X, y):
    # We create a 2-D array to store all accuracy values
    accuracy_row_list = []
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
        
    # Model intializing
    knn = KNeighborsClassifier(n_neighbors=3)

    # Training (very light compared to an eager learner)
    knn.fit(X_train, y_train)

    # Predicting on train and test set
    y_pred_train = knn.predict(X_train)
    y_pred_test = knn.predict(X_test)

    #print("KNN with k={}:".format(k))
        
    # Get the accuracy from metrics
    accuracy_train = accuracy_score(y_train, y_pred_train)
    #print("Training accuracy: {}".format(accuracy_train))
    accuracy_test = accuracy_score(y_test, y_pred_test)
    #print("Test accuracy: {}\r\n".format(accuracy_test))

    accuracy_row_list.append({"k": 3, "Training accuracy": accuracy_train, "Test accuracy": accuracy_test})

    return pd.DataFrame(accuracy_row_list)

# %%
def calculate_3nn(X, y):
    # We create a 2-D array to store all accuracy values
    accuracy_row_list = []

    # Model intializing
    knn = KNeighborsClassifier(n_neighbors=3)

    # Training (very light compared to an eager learner)
    knn.fit(X, y)
    y_pred = knn.predict(X)
        
    # Get the accuracy from metrics
    accuracy_test = accuracy_score(y, y_pred)
    print("Test accuracy: {}\r\n".format(accuracy_test))

    correct_predictions = np.sum(y == y_pred)
    print("correct prediction count: {}\r\n".format(correct_predictions))

    accuracy_row_list.append({"k": 3, "Test accuracy": accuracy_test, "Number of correct classifications": correct_predictions})

    return pd.DataFrame(accuracy_row_list)

# %%
import paho.mqtt.client as mqtt
from io import StringIO

# This function defines what to do when we connect to the broker
def on_connect(client, userdata, flags, rc):
    print("Connected with result code " + str(rc))
    # We subscribe to this particular data. There may be other data published by the same subscriber or broker.
    client.subscribe("myroom_super_S/S")

# This function defines what to do when we receives a message from the brokder
def on_message(client, userdata, msg):
    global my_index 
    my_index = my_index + 1
    temp_s = msg.payload.decode('utf-8')
    #print("Received myroom_super_S/S: ", temp_s)

    df_from_json = pd.read_json(StringIO(temp_s), orient='index')

    new_row = pd.DataFrame(df_from_json)
    global my_list_s

    my_list_s = pd.concat([my_list_s, new_row], ignore_index=True)

    #print(my_list_s[-6:])
    
    if(len(my_list_s.index) > 5):
        #print("My list: ", my_list_s)
        #print("End of list!")

        if(my_index % 5): # train every 5 new data, could then probably just send the 5 data as one piece as well
            x = my_list_s[["Glucose", "BloodPressure", "Insulin"]]
            y = my_list_s["Outcome"]
            y = y.astype(int) # it was interpreted as a wrong type, it thought it was float but it is an int, 0 or 1
            
            result = calculate_3nn(x, y)
            global my_list_classification
            my_list_classification = pd.concat([my_list_classification, result], ignore_index=True)
            print(result)   

    if(my_index >= 1000):
        print("We are DONE")
        print()
        print("The result: ", my_list_classification)

# We create a client as the data subscriber and specify its actions for particular events
mqttc = mqtt.Client()
mqttc.on_connect = on_connect 
mqttc.on_message = on_message
my_list_s = pd.DataFrame(columns=["Glucose", "BloodPressure", "Insulin", "Outcome"])
my_list_classification = pd.DataFrame(columns=["k", "Test accuracy", "Number of correct classifications"])
my_index = 0 # check length of my_list instead, then stop when list len is 1000 or over

# Now, we connect to the data broker.
mqttc.connect("mqtt.eclipseprojects.io", 1883, 60)

# As a simple example, we just keep the data listening/receiving on and on...
mqttc.loop_forever()
# Out:
# Connected with result code 0
# C:\Users\Bobby\AppData\Local\Temp\ipykernel_11384\2068524319.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   my_list_s = pd.concat([my_list_s, new_row], ignore_index=True)
# Test accuracy: 0.8333333333333334
#
# correct prediction count: 5
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.833333                                  5
# Test accuracy: 0.8571428571428571
#
# correct prediction count: 6
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.857143                                  6
# C:\Users\Bobby\AppData\Local\Temp\ipykernel_11384\2068524319.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   my_list_classification = pd.concat([my_list_classification, result], ignore_index=True)
# Test accuracy: 0.875
#
# correct prediction count: 7
#
#    k  Test accuracy  Number of correct classifications
# 0  3          0.875                                  7
# Test accuracy: 0.8888888888888888
#
# correct prediction count: 8
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.888889                                  8
# Test accuracy: 0.7272727272727273
#
# correct prediction count: 8
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.727273                                  8
# Test accuracy: 0.75
#
# correct prediction count: 9
#
#    k  Test accuracy  Number of correct classifications
# 0  3           0.75                                  9
# Test accuracy: 0.7692307692307693
#
# correct prediction count: 10
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.769231                                 10
# Test accuracy: 0.7857142857142857
#
# correct prediction count: 11
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.785714                                 11
# Test accuracy: 0.8125
#
# correct prediction count: 13
#
#    k  Test accuracy  Number of correct classifications
# 0  3         0.8125                                 13
# Test accuracy: 0.8235294117647058
#
# correct prediction count: 14
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.823529                                 14
# Test accuracy: 0.8333333333333334
#
# correct prediction count: 15
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.833333                                 15
# Test accuracy: 0.8421052631578947
#
# correct prediction count: 16
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.842105                                 16
# Test accuracy: 0.8571428571428571
#
# correct prediction count: 18
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.857143                                 18
# Test accuracy: 0.8636363636363636
#
# correct prediction count: 19
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.863636                                 19
# Test accuracy: 0.8260869565217391
#
# correct prediction count: 19
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.826087                                 19
# Test accuracy: 0.8333333333333334
#
# correct prediction count: 20
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.833333                                 20
# Test accuracy: 0.8076923076923077
#
# correct prediction count: 21
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.807692                                 21
# Test accuracy: 0.8148148148148148
#
# correct prediction count: 22
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.814815                                 22
# Test accuracy: 0.8214285714285714
#
# correct prediction count: 23
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.821429                                 23
# Test accuracy: 0.8275862068965517
#
# correct prediction count: 24
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.827586                                 24
# Test accuracy: 0.8387096774193549
#
# correct prediction count: 26
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.83871                                 26
# Test accuracy: 0.84375
#
# correct prediction count: 27
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.84375                                 27
# Test accuracy: 0.8484848484848485
#
# correct prediction count: 28
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.848485                                 28
# Test accuracy: 0.8529411764705882
#
# correct prediction count: 29
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.852941                                 29
# Test accuracy: 0.8611111111111112
#
# correct prediction count: 31
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.861111                                 31
# Test accuracy: 0.8648648648648649
#
# correct prediction count: 32
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.864865                                 32
# Test accuracy: 0.868421052631579
#
# correct prediction count: 33
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.868421                                 33
# Test accuracy: 0.8717948717948718
#
# correct prediction count: 34
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.871795                                 34
# Test accuracy: 0.8536585365853658
#
# correct prediction count: 35
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.853659                                 35
# Test accuracy: 0.8095238095238095
#
# correct prediction count: 34
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.809524                                 34
# Test accuracy: 0.813953488372093
#
# correct prediction count: 35
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.813953                                 35
# Test accuracy: 0.8181818181818182
#
# correct prediction count: 36
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.818182                                 36
# Test accuracy: 0.8260869565217391
#
# correct prediction count: 38
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.826087                                 38
# Test accuracy: 0.8297872340425532
#
# correct prediction count: 39
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.829787                                 39
# Test accuracy: 0.8125
#
# correct prediction count: 39
#
#    k  Test accuracy  Number of correct classifications
# 0  3         0.8125                                 39
# Test accuracy: 0.8163265306122449
#
# correct prediction count: 40
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.816327                                 40
# Test accuracy: 0.8235294117647058
#
# correct prediction count: 42
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.823529                                 42
# Test accuracy: 0.8269230769230769
#
# correct prediction count: 43
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.826923                                 43
# Test accuracy: 0.8113207547169812
#
# correct prediction count: 43
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.811321                                 43
# Test accuracy: 0.8333333333333334
#
# correct prediction count: 45
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.833333                                 45
# Test accuracy: 0.8392857142857143
#
# correct prediction count: 47
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.839286                                 47
# Test accuracy: 0.8245614035087719
#
# correct prediction count: 47
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.824561                                 47
# Test accuracy: 0.8275862068965517
#
# correct prediction count: 48
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.827586                                 48
# Test accuracy: 0.8305084745762712
#
# correct prediction count: 49
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.830508                                 49
# Test accuracy: 0.819672131147541
#
# correct prediction count: 50
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.819672                                 50
# Test accuracy: 0.8064516129032258
#
# correct prediction count: 50
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.806452                                 50
# Test accuracy: 0.8095238095238095
#
# correct prediction count: 51
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.809524                                 51
# Test accuracy: 0.8125
#
# correct prediction count: 52
#
#    k  Test accuracy  Number of correct classifications
# 0  3         0.8125                                 52
# Test accuracy: 0.803030303030303
#
# correct prediction count: 53
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.80303                                 53
# Test accuracy: 0.8059701492537313
#
# correct prediction count: 54
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.80597                                 54
# Test accuracy: 0.8088235294117647
#
# correct prediction count: 55
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.808824                                 55
# Test accuracy: 0.8115942028985508
#
# correct prediction count: 56
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.811594                                 56
# Test accuracy: 0.8450704225352113
#
# correct prediction count: 60
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.84507                                 60
# Test accuracy: 0.8472222222222222
#
# correct prediction count: 61
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.847222                                 61
# Test accuracy: 0.8493150684931506
#
# correct prediction count: 62
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.849315                                 62
# Test accuracy: 0.8378378378378378
#
# correct prediction count: 62
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.837838                                 62
# Test accuracy: 0.8421052631578947
#
# correct prediction count: 64
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.842105                                 64
# Test accuracy: 0.8441558441558441
#
# correct prediction count: 65
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.844156                                 65
# Test accuracy: 0.8461538461538461
#
# correct prediction count: 66
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.846154                                 66
# Test accuracy: 0.8481012658227848
#
# correct prediction count: 67
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.848101                                 67
# Test accuracy: 0.8518518518518519
#
# correct prediction count: 69
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.851852                                 69
# Test accuracy: 0.8536585365853658
#
# correct prediction count: 70
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.853659                                 70
# Test accuracy: 0.8554216867469879
#
# correct prediction count: 71
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.855422                                 71
# Test accuracy: 0.8571428571428571
#
# correct prediction count: 72
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.857143                                 72
# Test accuracy: 0.8604651162790697
#
# correct prediction count: 74
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.860465                                 74
# Test accuracy: 0.8620689655172413
#
# correct prediction count: 75
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.862069                                 75
# Test accuracy: 0.8636363636363636
#
# correct prediction count: 76
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.863636                                 76
# Test accuracy: 0.8651685393258427
#
# correct prediction count: 77
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.865169                                 77
# Test accuracy: 0.8681318681318682
#
# correct prediction count: 79
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.868132                                 79
# Test accuracy: 0.8695652173913043
#
# correct prediction count: 80
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.869565                                 80
# Test accuracy: 0.8817204301075269
#
# correct prediction count: 82
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.88172                                 82
# Test accuracy: 0.8829787234042553
#
# correct prediction count: 83
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.882979                                 83
# Test accuracy: 0.8854166666666666
#
# correct prediction count: 85
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.885417                                 85
# Test accuracy: 0.8762886597938144
#
# correct prediction count: 85
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.876289                                 85
# Test accuracy: 0.8775510204081632
#
# correct prediction count: 86
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.877551                                 86
# Test accuracy: 0.8787878787878788
#
# correct prediction count: 87
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.878788                                 87
# Test accuracy: 0.8811881188118812
#
# correct prediction count: 89
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.881188                                 89
# Test accuracy: 0.8725490196078431
#
# correct prediction count: 89
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.872549                                 89
# Test accuracy: 0.8640776699029126
#
# correct prediction count: 89
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.864078                                 89
# Test accuracy: 0.8653846153846154
#
# correct prediction count: 90
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.865385                                 90
# Test accuracy: 0.8679245283018868
#
# correct prediction count: 92
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.867925                                 92
# Test accuracy: 0.8691588785046729
#
# correct prediction count: 93
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.869159                                 93
# Test accuracy: 0.8703703703703703
#
# correct prediction count: 94
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.87037                                 94
# Test accuracy: 0.8807339449541285
#
# correct prediction count: 96
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.880734                                 96
# Test accuracy: 0.8738738738738738
#
# correct prediction count: 97
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.873874                                 97
# Test accuracy: 0.875
#
# correct prediction count: 98
#
#    k  Test accuracy  Number of correct classifications
# 0  3          0.875                                 98
# Test accuracy: 0.8761061946902655
#
# correct prediction count: 99
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.876106                                 99
# Test accuracy: 0.8771929824561403
#
# correct prediction count: 100
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.877193                                100
# Test accuracy: 0.8793103448275862
#
# correct prediction count: 102
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.87931                                102
# Test accuracy: 0.8803418803418803
#
# correct prediction count: 103
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.880342                                103
# Test accuracy: 0.8813559322033898
#
# correct prediction count: 104
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.881356                                104
# Test accuracy: 0.8823529411764706
#
# correct prediction count: 105
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.882353                                105
# Test accuracy: 0.8842975206611571
#
# correct prediction count: 107
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.884298                                107
# Test accuracy: 0.8852459016393442
#
# correct prediction count: 108
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.885246                                108
# Test accuracy: 0.8861788617886179
#
# correct prediction count: 109
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.886179                                109
# Test accuracy: 0.8790322580645161
#
# correct prediction count: 109
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.879032                                109
# Test accuracy: 0.8809523809523809
#
# correct prediction count: 111
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.880952                                111
# Test accuracy: 0.8818897637795275
#
# correct prediction count: 112
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.88189                                112
# Test accuracy: 0.8828125
#
# correct prediction count: 113
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.882812                                113
# Test accuracy: 0.8914728682170543
#
# correct prediction count: 115
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.891473                                115
# Test accuracy: 0.8931297709923665
#
# correct prediction count: 117
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.89313                                117
# Test accuracy: 0.8863636363636364
#
# correct prediction count: 117
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.886364                                117
# Test accuracy: 0.8796992481203008
#
# correct prediction count: 117
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.879699                                117
# Test accuracy: 0.8805970149253731
#
# correct prediction count: 118
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.880597                                118
# Test accuracy: 0.875
#
# correct prediction count: 119
#
#    k  Test accuracy  Number of correct classifications
# 0  3          0.875                                119
# Test accuracy: 0.8686131386861314
#
# correct prediction count: 119
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.868613                                119
# Test accuracy: 0.8695652173913043
#
# correct prediction count: 120
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.869565                                120
# Test accuracy: 0.8561151079136691
#
# correct prediction count: 119
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.856115                                119
# Test accuracy: 0.851063829787234
#
# correct prediction count: 120
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.851064                                120
# Test accuracy: 0.852112676056338
#
# correct prediction count: 121
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.852113                                121
# Test accuracy: 0.8601398601398601
#
# correct prediction count: 123
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.86014                                123
# Test accuracy: 0.8611111111111112
#
# correct prediction count: 124
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.861111                                124
# Test accuracy: 0.863013698630137
#
# correct prediction count: 126
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.863014                                126
# Test accuracy: 0.8639455782312925
#
# correct prediction count: 127
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.863946                                127
# Test accuracy: 0.8648648648648649
#
# correct prediction count: 128
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.864865                                128
# Test accuracy: 0.8657718120805369
#
# correct prediction count: 129
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.865772                                129
# Test accuracy: 0.8675496688741722
#
# correct prediction count: 131
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.86755                                131
# Test accuracy: 0.868421052631579
#
# correct prediction count: 132
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.868421                                132
# Test accuracy: 0.8627450980392157
#
# correct prediction count: 132
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.862745                                132
# Test accuracy: 0.8636363636363636
#
# correct prediction count: 133
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.863636                                133
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[236], line 57
#      54 mqttc.connect("mqtt.eclipseprojects.io", 1883, 60)
#      56 # As a simple example, we just keep the data listening/receiving on and on...
# ---> 57 mqttc.loop_forever()
#
# File ~\anaconda3\Lib\site-packages\paho\mqtt\client.py:1750, in Client.loop_forever(self, timeout, max_packets, retry_first_connection)
#    1748 rc = MQTT_ERR_SUCCESS
#    1749 while rc == MQTT_ERR_SUCCESS:
# -> 1750     rc = self._loop(timeout)
#    1751     # We don't need to worry about locking here, because we've
#    1752     # either called loop_forever() when in single threaded mode, or
#    1753     # in multi threaded mode when loop_stop() has been called and
#    1754     # so no other threads can access _out_packet or _messages.
#    1755     if (self._thread_terminate is True
#    1756         and len(self._out_packet) == 0
#    1757             and len(self._out_messages) == 0):
#
# File ~\anaconda3\Lib\site-packages\paho\mqtt\client.py:1144, in Client._loop(self, timeout)
#    1141     rlist = [self._sock, self._sockpairR]
#    1143 try:
# -> 1144     socklist = select.select(rlist, wlist, [], timeout)
#    1145 except TypeError:
#    1146     # Socket isn't correct type, in likelihood connection is lost
#    1147     return MQTT_ERR_CONN_LOST
#
# KeyboardInterrupt:
