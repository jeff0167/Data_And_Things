# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv("../Notebooks and data-9/diabetes.csv") # this is just for reference to look at
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
X = df[["Glucose", "BloodPressure", "Insulin", "Outcome"]]
X
# Out:
#      Glucose  BloodPressure  Insulin  Outcome
# 0        148             72        0        1
# 1         85             66        0        0
# 2        183             64        0        1
# 3         89             66       94        0
# 4        137             40      168        1
# ..       ...            ...      ...      ...
# 763      101             76      180        0
# 764      122             70        0        0
# 765      121             72      112        0
# 766      126             60        0        1
# 767       93             70        0        0
#
# [768 rows x 4 columns]

# %%
y = df["Outcome"]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# The publisher publishes records in S continuously. When it reaches the end of S, it continues to send from the beginning again.
#
# The subscriber continuously receives the data. For each latest record(r) received, apply the 3NN classification to the last 5 records before r, and compare the classification result with the Outcome label in r.
#
#     Repeat this for 1000 times, and report the number of correct classifications.
#
#     Question: "apply the 3NN classification to the last 5 records before r" is ambigous, is it from 0 - (len(list) - 5) or (len(list) - 5) - len(list)
#     One intepretation would only ever test with the five latest records before r, the other would take all the records - the last 5 before r
#     one: 5, the other is ever increasing, and ever more acurate, though also ever more computational expensive
#     I must assume it would be the later, you want to train a model on new data in addition to what you already have to improve your model

# %%
def calculate_3nn_with_train_test(X, y):
    # We create a 2-D array to store all accuracy values
    accuracy_row_list = []
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
        
    # Model intializing
    knn = KNeighborsClassifier(n_neighbors=3)

    # Training (very light compared to an eager learner)
    knn.fit(X_train, y_train)

    # Predicting on train and test set
    y_pred_train = knn.predict(X_train)
    y_pred_test = knn.predict(X_test)

    #print("KNN with k={}:".format(k))
        
    # Get the accuracy from metrics
    accuracy_train = accuracy_score(y_train, y_pred_train)
    #print("Training accuracy: {}".format(accuracy_train))
    accuracy_test = accuracy_score(y_test, y_pred_test)
    #print("Test accuracy: {}\r\n".format(accuracy_test))

    accuracy_row_list.append({"k": 3, "Training accuracy": accuracy_train, "Test accuracy": accuracy_test})

    return pd.DataFrame(accuracy_row_list)

# %%
def calculate_3nn(X, y):
    # We create a 2-D array to store all accuracy values
    accuracy_row_list = []

    # Model intializing
    knn = KNeighborsClassifier(n_neighbors=3)

    # Training (very light compared to an eager learner)
    knn.fit(X, y)
    y_pred = knn.predict(X)
        
    # Get the accuracy from metrics
    accuracy_test = accuracy_score(y, y_pred)
    print("Test accuracy: {}\r\n".format(accuracy_test))

    correct_predictions = np.sum(y == y_pred)
    print("correct prediction count: {}\r\n".format(correct_predictions))

    accuracy_row_list.append({"k": 3, "Test accuracy": accuracy_test, "Number of correct classifications": correct_predictions})

    return pd.DataFrame(accuracy_row_list)

# %%
import paho.mqtt.client as mqtt
from io import StringIO

# This function defines what to do when we connect to the broker
def on_connect(client, userdata, flags, rc):
    print("Connected with result code " + str(rc))
    # We subscribe to this particular data. There may be other data published by the same subscriber or broker.
    client.subscribe("myroom_super_S/S")

# This function defines what to do when we receives a message from the brokder
def on_message(client, userdata, msg):
    global my_list_s
    if(len(my_list_s.index) < 1000):
        temp_s = msg.payload.decode('utf-8')
        #print("Received myroom_super_S/S: ", temp_s)
        
        df_from_json = pd.read_json(StringIO(temp_s), orient='index')
    
        new_row = pd.DataFrame(df_from_json)
    
        my_list_s = pd.concat([my_list_s, new_row], ignore_index=True)
    
        #print(my_list_s[-6:])
        
        if(len(my_list_s.index) > 5 and len(my_list_s.index) % 10 == 1): # train every 5 new data, could then probably just send the 5 data as one piece as well
            #print("My list: ", my_list_s)
            #print("End of list!")
    
            x = my_list_s[["Glucose", "BloodPressure", "Insulin"]]
            y = my_list_s["Outcome"]
            y = y.astype(int) # it was interpreted as a wrong type, it thought it was float but it is an int, 0 or 1
            
            result = calculate_3nn(x, y)
            global my_list_classification
            my_list_classification = pd.concat([my_list_classification, result], ignore_index=True)
            print(result)   
    else:
        global task_complete
        if(task_complete == -1):
            task_complete = 0

    if(task_complete == 0):
        task_complete = 1
        print("We are DONE")
        print()
        print("The result: ", my_list_classification)
        print("Total number of correct classifications: ", my_list_classification["Number of correct classifications"].max())
        best_row = my_list_classification[my_list_classification["Test accuracy"].max() == my_list_classification["Test accuracy"]]
        print("Best accuracy score: ", best_row)
        

# We create a client as the data subscriber and specify its actions for particular events
mqttc = mqtt.Client()
mqttc.on_connect = on_connect 
mqttc.on_message = on_message
my_list_s = pd.DataFrame(columns=["Glucose", "BloodPressure", "Insulin", "Outcome"])
my_list_classification = pd.DataFrame(columns=["k", "Test accuracy", "Number of correct classifications"])
task_complete = -1

# Now, we connect to the data broker.
mqttc.connect("mqtt.eclipseprojects.io", 1883, 60)

# As a simple example, we just keep the data listening/receiving on and on...
mqttc.loop_forever()
# Out:
# Connected with result code 0
# C:\Users\Bobby\AppData\Local\Temp\ipykernel_3312\3510089147.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   my_list_s = pd.concat([my_list_s, new_row], ignore_index=True)
# Test accuracy: 0.8181818181818182
#
# correct prediction count: 9
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.818182                                  9
# C:\Users\Bobby\AppData\Local\Temp\ipykernel_3312\3510089147.py:35: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   my_list_classification = pd.concat([my_list_classification, result], ignore_index=True)
# Test accuracy: 0.8095238095238095
#
# correct prediction count: 17
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.809524                                 17
# Test accuracy: 0.8709677419354839
#
# correct prediction count: 27
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.870968                                 27
# Test accuracy: 0.8292682926829268
#
# correct prediction count: 34
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.829268                                 34
# Test accuracy: 0.8431372549019608
#
# correct prediction count: 43
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.843137                                 43
# Test accuracy: 0.9016393442622951
#
# correct prediction count: 55
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.901639                                 55
# Test accuracy: 0.9014084507042254
#
# correct prediction count: 64
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.901408                                 64
# Test accuracy: 0.8888888888888888
#
# correct prediction count: 72
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.888889                                 72
# Test accuracy: 0.9120879120879121
#
# correct prediction count: 83
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.912088                                 83
# Test accuracy: 0.8910891089108911
#
# correct prediction count: 90
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.891089                                 90
# Test accuracy: 0.8648648648648649
#
# correct prediction count: 96
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.864865                                 96
# Test accuracy: 0.8677685950413223
#
# correct prediction count: 105
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.867769                                105
# Test accuracy: 0.8778625954198473
#
# correct prediction count: 115
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.877863                                115
# Test accuracy: 0.8723404255319149
#
# correct prediction count: 123
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.87234                                123
# Test accuracy: 0.8807947019867549
#
# correct prediction count: 133
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.880795                                133
# Test accuracy: 0.8757763975155279
#
# correct prediction count: 141
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.875776                                141
# Test accuracy: 0.8654970760233918
#
# correct prediction count: 148
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.865497                                148
# Test accuracy: 0.8453038674033149
#
# correct prediction count: 153
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.845304                                153
# Test accuracy: 0.837696335078534
#
# correct prediction count: 160
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.837696                                160
# Test accuracy: 0.8407960199004975
#
# correct prediction count: 169
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.840796                                169
# Test accuracy: 0.8483412322274881
#
# correct prediction count: 179
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.848341                                179
# Test accuracy: 0.8280542986425339
#
# correct prediction count: 183
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.828054                                183
# Test accuracy: 0.8311688311688312
#
# correct prediction count: 192
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.831169                                192
# Test accuracy: 0.8215767634854771
#
# correct prediction count: 198
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.821577                                198
# Test accuracy: 0.8207171314741036
#
# correct prediction count: 206
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.820717                                206
# Test accuracy: 0.8160919540229885
#
# correct prediction count: 213
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.816092                                213
# Test accuracy: 0.8191881918819188
#
# correct prediction count: 222
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.819188                                222
# Test accuracy: 0.8256227758007118
#
# correct prediction count: 232
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.825623                                232
# Test accuracy: 0.8178694158075601
#
# correct prediction count: 238
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.817869                                238
# Test accuracy: 0.8205980066445183
#
# correct prediction count: 247
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.820598                                247
# Test accuracy: 0.8263665594855305
#
# correct prediction count: 257
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.826367                                257
# Test accuracy: 0.8255451713395638
#
# correct prediction count: 265
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.825545                                265
# Test accuracy: 0.8308157099697885
#
# correct prediction count: 275
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.830816                                275
# Test accuracy: 0.8299120234604106
#
# correct prediction count: 283
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.829912                                283
# Test accuracy: 0.8347578347578347
#
# correct prediction count: 293
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.834758                                293
# Test accuracy: 0.8310249307479224
#
# correct prediction count: 300
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.831025                                300
# Test accuracy: 0.8140161725067385
#
# correct prediction count: 302
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.814016                                302
# Test accuracy: 0.800524934383202
#
# correct prediction count: 305
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.800525                                305
# Test accuracy: 0.80306905370844
#
# correct prediction count: 314
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.803069                                314
# Test accuracy: 0.8104738154613467
#
# correct prediction count: 325
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.810474                                325
# Test accuracy: 0.8199513381995134
#
# correct prediction count: 337
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.819951                                337
# Test accuracy: 0.8242280285035629
#
# correct prediction count: 347
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.824228                                347
# Test accuracy: 0.8167053364269141
#
# correct prediction count: 352
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.816705                                352
# Test accuracy: 0.8253968253968254
#
# correct prediction count: 364
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.825397                                364
# Test accuracy: 0.8270509977827051
#
# correct prediction count: 373
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.827051                                373
# Test accuracy: 0.824295010845987
#
# correct prediction count: 380
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.824295                                380
# Test accuracy: 0.8280254777070064
#
# correct prediction count: 390
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.828025                                390
# Test accuracy: 0.8316008316008316
#
# correct prediction count: 400
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.831601                                400
# Test accuracy: 0.8309572301425662
#
# correct prediction count: 408
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.830957                                408
# Test accuracy: 0.8303393213572854
#
# correct prediction count: 416
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.830339                                416
# Test accuracy: 0.8277886497064579
#
# correct prediction count: 423
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.827789                                423
# Test accuracy: 0.8349328214971209
#
# correct prediction count: 435
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.834933                                435
# Test accuracy: 0.8342749529190208
#
# correct prediction count: 443
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.834275                                443
# Test accuracy: 0.8280961182994455
#
# correct prediction count: 448
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.828096                                448
# Test accuracy: 0.8257713248638838
#
# correct prediction count: 455
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.825771                                455
# Test accuracy: 0.8288770053475936
#
# correct prediction count: 465
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.828877                                465
# Test accuracy: 0.8266199649737302
#
# correct prediction count: 472
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.82662                                472
# Test accuracy: 0.8296041308089501
#
# correct prediction count: 482
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.829604                                482
# Test accuracy: 0.8358714043993232
#
# correct prediction count: 494
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.835871                                494
# Test accuracy: 0.8286189683860233
#
# correct prediction count: 498
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.828619                                498
# Test accuracy: 0.8314238952536824
#
# correct prediction count: 508
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.831424                                508
# Test accuracy: 0.8325281803542673
#
# correct prediction count: 517
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.832528                                517
# Test accuracy: 0.8351822503961965
#
# correct prediction count: 527
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.835182                                527
# Test accuracy: 0.8315132605304212
#
# correct prediction count: 533
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.831513                                533
# Test accuracy: 0.8417818740399385
#
# correct prediction count: 548
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.841782                                548
# Test accuracy: 0.8426626323751891
#
# correct prediction count: 557
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.842663                                557
# Test accuracy: 0.842026825633383
#
# correct prediction count: 565
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.842027                                565
# Test accuracy: 0.8428781204111601
#
# correct prediction count: 574
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.842878                                574
# Test accuracy: 0.8379160636758322
#
# correct prediction count: 579
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.837916                                579
# Test accuracy: 0.8402282453637661
#
# correct prediction count: 589
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.840228                                589
# Test accuracy: 0.8410689170182841
#
# correct prediction count: 598
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.841069                                598
# Test accuracy: 0.8377253814147018
#
# correct prediction count: 604
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.837725                                604
# Test accuracy: 0.8399452804377565
#
# correct prediction count: 614
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.839945                                614
# Test accuracy: 0.8380566801619433
#
# correct prediction count: 621
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.838057                                621
# Test accuracy: 0.8322237017310253
#
# correct prediction count: 625
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.832224                                625
# Test accuracy: 0.835742444152431
#
# correct prediction count: 636
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.835742                                636
# Test accuracy: 0.8326848249027238
#
# correct prediction count: 642
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.832685                                642
# Test accuracy: 0.8297055057618438
#
# correct prediction count: 648
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.829706                                648
# Test accuracy: 0.8356510745891277
#
# correct prediction count: 661
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.835651                                661
# Test accuracy: 0.8414481897627965
#
# correct prediction count: 674
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.841448                                674
# Test accuracy: 0.843403205918619
#
# correct prediction count: 684
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.843403                                684
# Test accuracy: 0.8416565164433617
#
# correct prediction count: 691
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.841657                                691
# Test accuracy: 0.8411552346570397
#
# correct prediction count: 699
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.841155                                699
# Test accuracy: 0.8442330558858502
#
# correct prediction count: 710
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.844233                                710
# Test accuracy: 0.8448883666274971
#
# correct prediction count: 719
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.844888                                719
# Test accuracy: 0.8455284552845529
#
# correct prediction count: 728
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.845528                                728
# Test accuracy: 0.8507462686567164
#
# correct prediction count: 741
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.850746                                741
# Test accuracy: 0.8535754824063564
#
# correct prediction count: 752
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.853575                                752
# Test accuracy: 0.8574635241301908
#
# correct prediction count: 764
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.857464                                764
# Test accuracy: 0.855715871254162
#
# correct prediction count: 771
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.855716                                771
# Test accuracy: 0.858397365532382
#
# correct prediction count: 782
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.858397                                782
# Test accuracy: 0.8621064060803475
#
# correct prediction count: 794
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.862106                                794
# Test accuracy: 0.8614393125671321
#
# correct prediction count: 802
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.861439                                802
# Test accuracy: 0.8660998937300743
#
# correct prediction count: 815
#
#    k  Test accuracy  Number of correct classifications
# 0  3         0.8661                                815
# Test accuracy: 0.868559411146162
#
# correct prediction count: 826
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.868559                                826
# Test accuracy: 0.8688865764828304
#
# correct prediction count: 835
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.868887                                835
# Test accuracy: 0.8753861997940268
#
# correct prediction count: 850
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.875386                                850
# Test accuracy: 0.8766564729867482
#
# correct prediction count: 860
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.876656                                860
# Test accuracy: 0.8799192734611504
#
# correct prediction count: 872
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.879919                                872
# We are DONE
#
# The result:      k  Test accuracy Number of correct classifications
# 0   3       0.818182                                 9
# 1   3       0.809524                                17
# 2   3       0.870968                                27
# 3   3       0.829268                                34
# 4   3       0.843137                                43
# .. ..            ...                               ...
# 94  3       0.868559                               826
# 95  3       0.868887                               835
# 96  3       0.875386                               850
# 97  3       0.876656                               860
# 98  3       0.879919                               872
#
# [99 rows x 3 columns]
# Total number of correct classifications:  872
# Best accuracy score:     k  Test accuracy Number of correct classifications
# 8  3       0.912088                                83
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 64
#      61 mqttc.connect("mqtt.eclipseprojects.io", 1883, 60)
#      63 # As a simple example, we just keep the data listening/receiving on and on...
# ---> 64 mqttc.loop_forever()
#
# File ~\anaconda3\Lib\site-packages\paho\mqtt\client.py:1750, in Client.loop_forever(self, timeout, max_packets, retry_first_connection)
#    1748 rc = MQTT_ERR_SUCCESS
#    1749 while rc == MQTT_ERR_SUCCESS:
# -> 1750     rc = self._loop(timeout)
#    1751     # We don't need to worry about locking here, because we've
#    1752     # either called loop_forever() when in single threaded mode, or
#    1753     # in multi threaded mode when loop_stop() has been called and
#    1754     # so no other threads can access _out_packet or _messages.
#    1755     if (self._thread_terminate is True
#    1756         and len(self._out_packet) == 0
#    1757             and len(self._out_messages) == 0):
#
# File ~\anaconda3\Lib\site-packages\paho\mqtt\client.py:1144, in Client._loop(self, timeout)
#    1141     rlist = [self._sock, self._sockpairR]
#    1143 try:
# -> 1144     socklist = select.select(rlist, wlist, [], timeout)
#    1145 except TypeError:
#    1146     # Socket isn't correct type, in likelihood connection is lost
#    1147     return MQTT_ERR_CONN_LOST
#
# KeyboardInterrupt:
