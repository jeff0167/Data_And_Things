# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv("../Notebooks and data-9/diabetes.csv") # this is just for reference to look at
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
X = df[["Glucose", "BloodPressure", "Insulin", "Outcome"]]
X
# Out:
#      Glucose  BloodPressure  Insulin  Outcome
# 0        148             72        0        1
# 1         85             66        0        0
# 2        183             64        0        1
# 3         89             66       94        0
# 4        137             40      168        1
# ..       ...            ...      ...      ...
# 763      101             76      180        0
# 764      122             70        0        0
# 765      121             72      112        0
# 766      126             60        0        1
# 767       93             70        0        0
#
# [768 rows x 4 columns]

# %%
y = df["Outcome"]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# The publisher publishes records in S continuously. When it reaches the end of S, it continues to send from the beginning again.
#
# The subscriber continuously receives the data. For each latest record(r) received, apply the 3NN classification to the last 5 records before r, and compare the classification result with the Outcome label in r.
#
#     Repeat this for 1000 times, and report the number of correct classifications.
#
#     Question: "apply the 3NN classification to the last 5 records before r" is ambigous, is it from 0 - (len(list) - 5) or (len(list) - 5) - len(list)
#     One intepretation would only ever test with the five latest records before r, the other would take all the records - the last 5 before r
#     one: 5, the other is ever increasing, and ever more acurate, though also ever more computational expensive
#     I must assume it would be the later, you want to train a model on new data in addition to what you already have to improve your model

# %%
def calculate_3nn_with_train_test(X, y):
    # We create a 2-D array to store all accuracy values
    accuracy_row_list = []
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
        
    # Model intializing
    knn = KNeighborsClassifier(n_neighbors=3)

    # Training (very light compared to an eager learner)
    knn.fit(X_train, y_train)

    # Predicting on train and test set
    y_pred_train = knn.predict(X_train)
    y_pred_test = knn.predict(X_test)

    #print("KNN with k={}:".format(k))
        
    # Get the accuracy from metrics
    accuracy_train = accuracy_score(y_train, y_pred_train)
    #print("Training accuracy: {}".format(accuracy_train))
    accuracy_test = accuracy_score(y_test, y_pred_test)
    #print("Test accuracy: {}\r\n".format(accuracy_test))

    accuracy_row_list.append({"k": 3, "Training accuracy": accuracy_train, "Test accuracy": accuracy_test})

    return pd.DataFrame(accuracy_row_list)

# %%
def calculate_3nn(X, y):
    # We create a 2-D array to store all accuracy values
    accuracy_row_list = []

    # Model intializing
    knn = KNeighborsClassifier(n_neighbors=3)

    # Training (very light compared to an eager learner)
    knn.fit(X, y)
    y_pred = knn.predict(X)
        
    # Get the accuracy from metrics
    accuracy_test = accuracy_score(y, y_pred)
    print("Test accuracy: {}\r\n".format(accuracy_test))

    correct_predictions = np.sum(y == y_pred)
    print("correct prediction count: {}\r\n".format(correct_predictions))

    accuracy_row_list.append({"k": 3, "Test accuracy": accuracy_test, "Number of correct classifications": correct_predictions})

    return pd.DataFrame(accuracy_row_list)

# %%
import paho.mqtt.client as mqtt
from io import StringIO

# This function defines what to do when we connect to the broker
def on_connect(client, userdata, flags, rc):
    print("Connected with result code " + str(rc))
    # We subscribe to this particular data. There may be other data published by the same subscriber or broker.
    client.subscribe("myroom_super_S/S")

# This function defines what to do when we receives a message from the brokder
def on_message(client, userdata, msg):
    global my_list_s
    if(len(my_list_s.index) < 1000):
        temp_s = msg.payload.decode('utf-8')
        #print("Received myroom_super_S/S: ", temp_s)
        
        df_from_json = pd.read_json(StringIO(temp_s), orient='index')
    
        new_row = pd.DataFrame(df_from_json)
    
        my_list_s = pd.concat([my_list_s, new_row], ignore_index=True)
    
        #print(my_list_s[-6:])
        
        if(len(my_list_s.index) > 5 and len(my_list_s.index) % 10 == 1): # train every 5 new data, could then probably just send the 5 data as one piece as well
            #print("My list: ", my_list_s)
            #print("End of list!")
    
            x = my_list_s[["Glucose", "BloodPressure", "Insulin"]]
            y = my_list_s["Outcome"]
            y = y.astype(int) # it was interpreted as a wrong type, it thought it was float but it is an int, 0 or 1
            
            result = calculate_3nn(x, y)
            global my_list_classification
            my_list_classification = pd.concat([my_list_classification, result], ignore_index=True)
            print(result)   
    else:
        global task_complete
        if(task_complete == -1):
            task_complete = 0

    if(task_complete == 0):
        task_complete = 1
        print("We are DONE")
        print()
        print("The result: ", my_list_classification)
        print("Total number of correct classifications: ", my_list_classification["Number of correct classifications"].max())
        best_row = my_list_classification[my_list_classification["Test accuracy"].max() == my_list_classification["Test accuracy"]]
        print("Best accuracy score: ", best_row)
        

# We create a client as the data subscriber and specify its actions for particular events
mqttc = mqtt.Client()
mqttc.on_connect = on_connect 
mqttc.on_message = on_message
my_list_s = pd.DataFrame(columns=["Glucose", "BloodPressure", "Insulin", "Outcome"])
my_list_classification = pd.DataFrame(columns=["k", "Test accuracy", "Number of correct classifications"])
task_complete = -1

# Now, we connect to the data broker.
mqttc.connect("mqtt.eclipseprojects.io", 1883, 60)

# As a simple example, we just keep the data listening/receiving on and on...
mqttc.loop_forever()
# Out:
# Connected with result code 0
# C:\Users\Bobby\AppData\Local\Temp\ipykernel_3312\4183220352.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   my_list_s = pd.concat([my_list_s, new_row], ignore_index=True)
# Test accuracy: 0.8181818181818182
#
# correct prediction count: 9
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.818182                                  9
# C:\Users\Bobby\AppData\Local\Temp\ipykernel_3312\4183220352.py:35: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   my_list_classification = pd.concat([my_list_classification, result], ignore_index=True)
# Test accuracy: 0.8571428571428571
#
# correct prediction count: 18
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.857143                                 18
# Test accuracy: 0.8387096774193549
#
# correct prediction count: 26
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.83871                                 26
# Test accuracy: 0.8536585365853658
#
# correct prediction count: 35
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.853659                                 35
# Test accuracy: 0.9019607843137255
#
# correct prediction count: 46
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.901961                                 46
# Test accuracy: 0.9016393442622951
#
# correct prediction count: 55
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.901639                                 55
# Test accuracy: 0.8591549295774648
#
# correct prediction count: 61
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.859155                                 61
# Test accuracy: 0.8765432098765432
#
# correct prediction count: 71
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.876543                                 71
# Test accuracy: 0.8461538461538461
#
# correct prediction count: 77
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.846154                                 77
# Test accuracy: 0.8514851485148515
#
# correct prediction count: 86
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.851485                                 86
# Test accuracy: 0.8918918918918919
#
# correct prediction count: 99
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.891892                                 99
# Test accuracy: 0.8760330578512396
#
# correct prediction count: 106
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.876033                                106
# Test accuracy: 0.8854961832061069
#
# correct prediction count: 116
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.885496                                116
# Test accuracy: 0.900709219858156
#
# correct prediction count: 127
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.900709                                127
# Test accuracy: 0.8940397350993378
#
# correct prediction count: 135
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.89404                                135
# Test accuracy: 0.8881987577639752
#
# correct prediction count: 143
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.888199                                143
# Test accuracy: 0.8771929824561403
#
# correct prediction count: 150
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.877193                                150
# Test accuracy: 0.8674033149171271
#
# correct prediction count: 157
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.867403                                157
# Test accuracy: 0.8691099476439791
#
# correct prediction count: 166
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.86911                                166
# Test accuracy: 0.8557213930348259
#
# correct prediction count: 172
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.855721                                172
# Test accuracy: 0.8530805687203792
#
# correct prediction count: 180
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.853081                                180
# Test accuracy: 0.8371040723981901
#
# correct prediction count: 185
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.837104                                185
# Test accuracy: 0.8311688311688312
#
# correct prediction count: 192
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.831169                                192
# Test accuracy: 0.8298755186721992
#
# correct prediction count: 200
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.829876                                200
# Test accuracy: 0.8366533864541833
#
# correct prediction count: 210
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.836653                                210
# Test accuracy: 0.8275862068965517
#
# correct prediction count: 216
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.827586                                216
# Test accuracy: 0.8191881918819188
#
# correct prediction count: 222
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.819188                                222
# Test accuracy: 0.8185053380782918
#
# correct prediction count: 230
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.818505                                230
# Test accuracy: 0.8247422680412371
#
# correct prediction count: 240
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.824742                                240
# Test accuracy: 0.8239202657807309
#
# correct prediction count: 248
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.82392                                248
# Test accuracy: 0.8263665594855305
#
# correct prediction count: 257
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.826367                                257
# Test accuracy: 0.8348909657320872
#
# correct prediction count: 268
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.834891                                268
# Test accuracy: 0.8338368580060423
#
# correct prediction count: 276
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.833837                                276
# Test accuracy: 0.8387096774193549
#
# correct prediction count: 286
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.83871                                286
# Test accuracy: 0.8404558404558404
#
# correct prediction count: 295
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.840456                                295
# Test accuracy: 0.850415512465374
#
# correct prediction count: 307
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.850416                                307
# Test accuracy: 0.8571428571428571
#
# correct prediction count: 318
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.857143                                318
# Test accuracy: 0.8503937007874016
#
# correct prediction count: 324
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.850394                                324
# Test accuracy: 0.8542199488491049
#
# correct prediction count: 334
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.85422                                334
# Test accuracy: 0.8503740648379052
#
# correct prediction count: 341
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.850374                                341
# Test accuracy: 0.8442822384428224
#
# correct prediction count: 347
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.844282                                347
# Test accuracy: 0.838479809976247
#
# correct prediction count: 353
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.83848                                353
# Test accuracy: 0.8352668213457076
#
# correct prediction count: 360
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.835267                                360
# Test accuracy: 0.8344671201814059
#
# correct prediction count: 368
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.834467                                368
# Test accuracy: 0.835920177383592
#
# correct prediction count: 377
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.83592                                377
# Test accuracy: 0.8373101952277657
#
# correct prediction count: 386
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.83731                                386
# Test accuracy: 0.8237791932059448
#
# correct prediction count: 388
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.823779                                388
# Test accuracy: 0.8253638253638254
#
# correct prediction count: 397
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.825364                                397
# Test accuracy: 0.824847250509165
#
# correct prediction count: 405
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.824847                                405
# Test accuracy: 0.8243512974051896
#
# correct prediction count: 413
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.824351                                413
# Test accuracy: 0.8238747553816047
#
# correct prediction count: 421
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.823875                                421
# Test accuracy: 0.8214971209213052
#
# correct prediction count: 428
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.821497                                428
# Test accuracy: 0.8210922787193974
#
# correct prediction count: 436
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.821092                                436
# Test accuracy: 0.8151571164510166
#
# correct prediction count: 441
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.815157                                441
# Test accuracy: 0.8130671506352087
#
# correct prediction count: 448
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.813067                                448
# Test accuracy: 0.8146167557932263
#
# correct prediction count: 457
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.814617                                457
# Test accuracy: 0.8143607705779334
#
# correct prediction count: 465
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.814361                                465
# Test accuracy: 0.8089500860585198
#
# correct prediction count: 470
#
#    k  Test accuracy  Number of correct classifications
# 0  3        0.80895                                470
# Test accuracy: 0.8087986463620981
#
# correct prediction count: 478
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.808799                                478
# Test accuracy: 0.8136439267886856
#
# correct prediction count: 489
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.813644                                489
# Test accuracy: 0.8134206219312602
#
# correct prediction count: 497
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.813421                                497
# Test accuracy: 0.8132045088566827
#
# correct prediction count: 505
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.813205                                505
# Test accuracy: 0.820919175911252
#
# correct prediction count: 518
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.820919                                518
# Test accuracy: 0.8159126365054602
#
# correct prediction count: 523
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.815913                                523
# Test accuracy: 0.8202764976958525
#
# correct prediction count: 534
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.820276                                534
# Test accuracy: 0.8154311649016641
#
# correct prediction count: 539
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.815431                                539
# Test accuracy: 0.819672131147541
#
# correct prediction count: 550
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.819672                                550
# Test accuracy: 0.8208516886930984
#
# correct prediction count: 559
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.820852                                559
# Test accuracy: 0.8219971056439942
#
# correct prediction count: 568
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.821997                                568
# Test accuracy: 0.8288159771754636
#
# correct prediction count: 581
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.828816                                581
# Test accuracy: 0.8312236286919831
#
# correct prediction count: 591
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.831224                                591
# Test accuracy: 0.8321775312066574
#
# correct prediction count: 600
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.832178                                600
# Test accuracy: 0.8344733242134063
#
# correct prediction count: 610
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.834473                                610
# Test accuracy: 0.8326585695006747
#
# correct prediction count: 617
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.832659                                617
# Test accuracy: 0.8308921438082557
#
# correct prediction count: 624
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.830892                                624
# Test accuracy: 0.8318002628120894
#
# correct prediction count: 633
#
#    k  Test accuracy  Number of correct classifications
# 0  3         0.8318                                633
# Test accuracy: 0.833981841763943
#
# correct prediction count: 643
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.833982                                643
# Test accuracy: 0.8361075544174136
#
# correct prediction count: 653
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.836108                                653
# Test accuracy: 0.8419721871049305
#
# correct prediction count: 666
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.841972                                666
# Test accuracy: 0.8401997503121099
#
# correct prediction count: 673
#
#    k  Test accuracy  Number of correct classifications
# 0  3         0.8402                                673
# Test accuracy: 0.8397040690505548
#
# correct prediction count: 681
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.839704                                681
# Test accuracy: 0.8416565164433617
#
# correct prediction count: 691
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.841657                                691
# Test accuracy: 0.8447653429602888
#
# correct prediction count: 702
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.844765                                702
# Test accuracy: 0.8466111771700356
#
# correct prediction count: 712
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.846611                                712
# Test accuracy: 0.8472385428907168
#
# correct prediction count: 721
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.847239                                721
# Test accuracy: 0.8501742160278746
#
# correct prediction count: 732
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.850174                                732
# Test accuracy: 0.8541905855338691
#
# correct prediction count: 744
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.854191                                744
# Test accuracy: 0.8547105561861521
#
# correct prediction count: 753
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.854711                                753
# Test accuracy: 0.8574635241301908
#
# correct prediction count: 764
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.857464                                764
# Test accuracy: 0.8601553829078802
#
# correct prediction count: 775
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.860155                                775
# Test accuracy: 0.8649835345773875
#
# correct prediction count: 788
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.864984                                788
# Test accuracy: 0.8599348534201955
#
# correct prediction count: 792
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.859935                                792
# Test accuracy: 0.8635875402792696
#
# correct prediction count: 804
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.863588                                804
# Test accuracy: 0.8650371944739639
#
# correct prediction count: 814
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.865037                                814
# Test accuracy: 0.8675078864353313
#
# correct prediction count: 825
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.867508                                825
# Test accuracy: 0.8678459937565036
#
# correct prediction count: 834
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.867846                                834
# Test accuracy: 0.8712667353244078
#
# correct prediction count: 846
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.871267                                846
# Test accuracy: 0.8766564729867482
#
# correct prediction count: 860
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.876656                                860
# Test accuracy: 0.8768920282542886
#
# correct prediction count: 869
#
#    k  Test accuracy  Number of correct classifications
# 0  3       0.876892                                869
# We are DONE
#
# The result:      k  Test accuracy Number of correct classifications  \
# 0   3       0.818182                                 9
# 1   3       0.857143                                18
# 2   3       0.838710                                26
# 3   3       0.853659                                35
# 4   3       0.901961                                46
# .. ..            ...                               ...
# 94  3       0.867508                               825
# 95  3       0.867846                               834
# 96  3       0.871267                               846
# 97  3       0.876656                               860
# 98  3       0.876892                               869
#
#     TotalCorrectClassifications
# 0                         41702
# 1                         41702
# 2                         41702
# 3                         41702
# 4                         41702
# ..                          ...
# 94                        41702
# 95                        41702
# 96                        41702
# 97                        41702
# 98                        41702
#
# [99 rows x 4 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 62
#      59 mqttc.connect("mqtt.eclipseprojects.io", 1883, 60)
#      61 # As a simple example, we just keep the data listening/receiving on and on...
# ---> 62 mqttc.loop_forever()
#
# File ~\anaconda3\Lib\site-packages\paho\mqtt\client.py:1750, in Client.loop_forever(self, timeout, max_packets, retry_first_connection)
#    1748 rc = MQTT_ERR_SUCCESS
#    1749 while rc == MQTT_ERR_SUCCESS:
# -> 1750     rc = self._loop(timeout)
#    1751     # We don't need to worry about locking here, because we've
#    1752     # either called loop_forever() when in single threaded mode, or
#    1753     # in multi threaded mode when loop_stop() has been called and
#    1754     # so no other threads can access _out_packet or _messages.
#    1755     if (self._thread_terminate is True
#    1756         and len(self._out_packet) == 0
#    1757             and len(self._out_messages) == 0):
#
# File ~\anaconda3\Lib\site-packages\paho\mqtt\client.py:1144, in Client._loop(self, timeout)
#    1141     rlist = [self._sock, self._sockpairR]
#    1143 try:
# -> 1144     socklist = select.select(rlist, wlist, [], timeout)
#    1145 except TypeError:
#    1146     # Socket isn't correct type, in likelihood connection is lost
#    1147     return MQTT_ERR_CONN_LOST
#
# KeyboardInterrupt:
