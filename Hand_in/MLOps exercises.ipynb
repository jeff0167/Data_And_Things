# %% [markdown]
# # MLOps exercises

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

import mlflow
import mlflow.sklearn

import tempfile

from sklearn import linear_model
from sklearn.model_selection import train_test_split 
from sklearn.metrics import  mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor

# %% [markdown]
# ## Execise 1
#
# In this exercise, do the following:
# 1. Create a function that preprocess new ames data in the same way as the original ames data was preprocessed in step 5 in the `MLOps.ipynb` notebook.
# 2. Create a function that takes as input a new ames dataset and a model. The function should pre-process the new data and evaluate the model on that new data using mean absolute error.
# 3. Test the function from 2. on the "NewAmesData1.csv" dataset and the best model from the `MLOps.ipynb` notebook.
# 4. Test the function from 2. on the "NewAmesData2.csv" dataset and the best model from the `MLOps.ipynb` notebook. Do you see any drift?
# 5. Do you see a data drift in "NewAmesData2.csv"? If so, for which variables?
# 6. Do you see a data drift in "NewAmesData4.csv"? If so, for which variables?
# 7. Create a function that retrain a model on the new data as well as the old training data
# 8. Retrain the `model_final` on the new data "NewAmesData1.csv" as well as the old training data, using the function from 5. Then test the new model on the old testset.
# 9. Split the "NewAmesData2.csv" dataset into a train and test set. Train  the best model from the `MLOps.ipynb` notebook on the training part and test it on the test part. Did you get a better model? Now combine your new training data with the original training data and retrain the model on that. Did that give you a better model?

# %% [markdown]
# ### 1. Create a function that preprocess new ames data in the same way as the original ames data was preprocessed in step 5 in the MLOps.ipynb notebook.

# %%
# extract
def extract(file):
    return pd.read_csv("../Notebooks and data-12/Data/" + file)

# transform
def pre_process(df):
    new_ames = df.copy()
    new_ames = new_ames.join(pd.get_dummies(new_ames["Bldg Type"], drop_first=True, dtype = "int", prefix="BType"))
    new_ames = new_ames.join(pd.get_dummies(new_ames["Neighborhood"], drop_first=True, dtype = "int", prefix="Nbh"))
    new_ames = new_ames.drop(columns = ["Bldg Type", "Neighborhood"])

    return new_ames

# %% [markdown]
# ### 2. Create a function that takes as input a new ames dataset and a model. The function should pre-process the new data and evaluate the model on that new data using mean absolute error.

# %%
#!pip freeze > requirements.txt ## IMPORTANT

#pip install -r /path/to/requirements.txt

# %%
data1.columns
# Out:
# Index(['Lot Area', 'Overall Cond', 'Year Built', 'Gr Liv Area',
#        'TotRms AbvGrd', 'Mo Sold', 'Yr Sold', 'Bldg Type', 'Neighborhood',
#        'SalePrice'],
#       dtype='object')

# %%
mlflow.set_experiment("MLFlow Housing data Example")

results = []

def evaluate_model(model, model_name, data):

    data = pre_process(data)
    with mlflow.start_run():
        X_ames = data.drop(columns=["SalePrice"])
        y_ames = data.SalePrice
        X_train, X_test, y_train, y_test = train_test_split(X_ames, y_ames, test_size=0.2, random_state=42)
    
        # Log feature combination and model type
        mlflow.log_param("features", data.columns)
        mlflow.log_param("model_type", model)
        
        model.fit(X_train, y_train)
        y_test_predictions = model.predict(X_test)       
    
        MAE = mean_absolute_error(y_test, y_test_predictions)

        # Log metrics
        mlflow.log_metric("MAE", MAE)
        
        # Create and log a plot of the metrics,    the plot should be showing the prediction vs actual for the test
        fig, ax = plt.rcParams['figure.figsize'] = [8, 8]
        ames = X_test[['Lot Area', 'Overall Cond', 'Year Built', 'Gr Liv Area', 'TotRms AbvGrd', 'Mo Sold', 'Yr Sold']].copy()
        ames["SalePrice"] = y_test
        ames.hist()
        
        # Save the plot to a temporary file and log it as an artifact
        temp_file = tempfile.NamedTemporaryFile(suffix=".png", delete=False)
        plt.savefig(temp_file.name)
        mlflow.log_artifact(temp_file.name, artifact_path="plots")
        temp_file.close()

       # Log the model
        mlflow.sklearn.log_model(model, model_name)
        
        # Store results for summary
        results.append({
            "MAE": MAE,
            "model": model_name,
        })
        
# Print summary of results
results_df = pd.DataFrame(results)
print("\nSummary of Experiment Results:")
print(results_df)
# Out:
# Summary of Experiment Results:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 3. Test the function from 2. on the "NewAmesData1.csv" dataset and the best model from the MLOps.ipynb notebook.

# %%
data0 = extract("AmesHousing.csv")
data1 = extract("NewAmesData1.csv")
data2 = extract("NewAmesData2.csv")
data4 = extract("NewAmesData4.csv")

# %%
model_final = RandomForestRegressor(n_estimators=500)

# %%
evaluate_model(model_final, "gradient boosting regressor", data1)

# %% [markdown]
# ### 4. Test the function from 2. on the "NewAmesData2.csv" dataset and the best model from the MLOps.ipynb notebook. Do you see any drift?

# %%
evaluate_model(model_final, "gradient boosting regressor", data2)

# %% [markdown]
# ### 5. Do you see a data drift in "NewAmesData2.csv"? If so, for which variables?

# %%
data1
# Out:
#      Lot Area  Overall Cond  Year Built  Gr Liv Area  TotRms AbvGrd  Mo Sold  \
# 0       10738             6        1954         1457              5        8
# 1       13835             4        1989         1792              6        3
# 2        9667             5        1997         1103              6        5
# 3       10699             6        2000         1671              6        4
# 4       14033             4        1992         1357              5       10
# ..        ...           ...         ...          ...            ...      ...
# 744      8944             5        1994         1947              7       12
# 745     11099             5        2014         1706              6        7
# 746      6271             5        1928         1373              6       11
# 747     10375             4        1980         1295              5        7
# 748      8732             7        1965         1574              7        6
#
#      Yr Sold Bldg Type Neighborhood  SalePrice
# 0       2009      1Fam        NAmes     132661
# 1       2006      1Fam      NridgHt     372144
# 2       2010      1Fam      SawyerW     150786
# 3       2009      1Fam      CollgCr     211081
# 4       2009      1Fam      Mitchel     142802
# ..       ...       ...          ...        ...
# 744     2007      1Fam      Somerst     271926
# 745     2009      1Fam      NridgHt     254630
# 746     2007      1Fam      BrkSide     127650
# 747     2009      1Fam      Mitchel     130559
# 748     2006    2fmCon        NAmes     184450
#
# [749 rows x 10 columns]

# %%
data2
# Out:
#      Lot Area  Overall Cond  Year Built  Gr Liv Area  TotRms AbvGrd  Mo Sold  \
# 0       10738             6        1954         1457              5        8
# 1       13835             4        1989         1792              6        3
# 2        9667             5        1997         1103              6        5
# 3       10699             6        2000         1671              6        4
# 4       14033             4        1992         1357              5       10
# ..        ...           ...         ...          ...            ...      ...
# 744      8944             5        1994         1947              7       12
# 745     11099             5        2014         1706              6        7
# 746      6271             5        1928         1373              6       11
# 747     10375             4        1980         1295              5        7
# 748      8732             7        1965         1574              7        6
#
#      Yr Sold Bldg Type Neighborhood    SalePrice
# 0       2009      1Fam        NAmes   -9790.3818
# 1       2006      1Fam      NridgHt  286779.5056
# 2       2010      1Fam      SawyerW    5021.1738
# 3       2009      1Fam      CollgCr  414742.1677
# 4       2009      1Fam      Mitchel  -57592.0466
# ..       ...       ...          ...          ...
# 744     2007      1Fam      Somerst  458212.1152
# 745     2009      1Fam      NridgHt  401512.8926
# 746     2007      1Fam      BrkSide   47600.6850
# 747     2009      1Fam      Mitchel   -4895.9625
# 748     2006    2fmCon        NAmes   23388.2600
#
# [749 rows x 10 columns]

# %% [markdown]
#     The data for both are completely the same and have the same shape, so no drift

# %% [markdown]
# ### 6. Do you see a data drift in "NewAmesData4.csv"? If so, for which variables?

# %%
evaluate_model(model_final, "gradient boosting regressor", data1)

# %%
evaluate_model(model_final, "gradient boosting regressor", data4)

# %% [markdown]
#     Some of the data from NewAmesData4 have longer x and y axes intervals, making it a bit harder to tell(new data)
#     This is a drift in itself, fx. GR Liv Area when from maximum of about 30 in the old to 125 in the new
#     Some of the new data also has much higher values leading to the majority of the graphs be more centered to the left in the new data
#     Month sold does seem to be negatively drifted from the maximum point, meaning there was more sales in the beginning of the year in the new data
#     All of this would indicate Feature drift, the distribution of features are changing, possible concept drift
